# %% [markdown]
# **INFORMAÇÕES RELEVANTES SOBRE A BIBLIOTECA PANDAS/SEABORN**

# %%
#DISCLAIMER IMPORTANTE

# o comando help(função) também pode ser de grande ajuda para verificar os demais elementos que possuem os requisitos.

# Biblioteca sys contém funções do sistema, podemos usar para medir o tamanho código
# Biblioteca time contém funções de tempo, podemos usar para medir o tempo de execução do código

# O python sempre considera o 0 para navegar entre os dados

# Fórmulas do pandas quer podem ser úteis:

# import pandas as pd -  importando a biblioteca
# import numpy as np -  importando a biblioteca numpy, vital para trabalhar com pandas
# import matplotlib.pyplot as plt  -  importando a biblioteca matplotlib, vital para trabalhar com pandas
# import seaborn as sns  -  importando a biblioteca seaborn, vital para trabalhar com seaborn

# dataframe = pd.read_csv('teste.csv', sep = ';') - importa um arquivo do tipo csv.
# dataframe.head() - traz a cabeça dos dados, as primeiras 5 linhas, se não definirmos quantidade
# dataframe.tail() - traz a calda dos dados, as ultimas 5 linhas, se não definirmos quantidade
# dataframe.shape - comando exibe quantidade de linhas e colunas.
# dataframe['coluna'] = pd.to_datetime(dataframe['coluna']) - transforma uma coluna para o tipo data.

# dataframe = pd.DataFrame({}) - criação de um dataframe em formato de dicionário para que possamos aplicar a manipulação panda.
# por se tratar de um dicionário, o nome das colunas serão as keys e seus values os respectivos valores 

# np.random.randint(vmin,vmax, size= n de termos) - seleção random de numeros inteiros
# np.random.choice(array especifico, size=n de termos) - seleção random de termos dentro de um array
# pd.date_range('2000-01-01', '2000-01-31') - criação de um array de datas com início e fim
# np.random.uniform(vmin,vmax, size= n de termos) - seleção random de numeros float
# lembrando, sempre que trabalhamos com array de valores, podemos setar um seed: seed = 0 , np.random.seed(seed)
# dataframe.info() - traz as informações pertinente aos dados, como os nulos, tipo das colunas, tamanho do range e outros mais
# dataframe.isna() - demonstra o que é nulo e o que não é, pode ser usado como dataframe.isna().any()
# dataframe.describe() - traz as informações pertinente aos valores, min/max e outros mais
# dataframe.describe(include='all') - traz as informações pertinente aos valores com mais detalhes
# dataframe.sample(frac=porcentual dos dados, random_state=seed) - traz uma amostra de uma % do dataframe para analise
# dataframe.sample(frac=porcentual dos dados, random_state=seed).index - indexa a localização dos dados
# dataframe.loc[index] - localiza o index dado dentro do dataframe, iloc pode ser usado para localizar posições
# dataframe.loc[index] - ex de uso:

#     seed = 0
#     busca_ix = dataframe.sample(frac=.2, random_state=seed).index
#     dataframe.loc[busca_ix (linhas), 'coluna x' (coluna)]

# np.nan - converte um valor em null, NaN, not a number
#dataframe.fillna() - preenche os valores nulos com um valor determinado, formas de uso:

#     dataframe.fillna("valor", inplace=True)
#     dataframe = dataframe.fillna("valor")

# podemos criar filtros para remover valores indesejados do dataframe, usando padrões e mascaras, ex:

#     gt_80 = dataframe['coluna desejada'] > 80
#     lt_18 = dataframe['coluna desejada'] < 18
#     filtro = gt_80 ( "|" para or ou "&" para and) lt_18
#     dataframe[~filtro] (valores estão fora do filtro) - dataframe[filtro] (valores estão dentro do filtro)
#     dataframe = dataframe[~filtro] remove os filtros
#     dataframe = dataframe[filtro] mantém somente os filtros

# podemos criar novas colunas no nosso dataframe, apenas inserindo um parametro simples:

#     dataframe['coluna_nova'] = dataframe[coluna_velha] >= 100
#     preenche com bool - True ou False

# dataframe['coluna'].value_counts() - conta os valores de uma coluna

# dataframe['dia_semana'] = dataframe.data.dt.weekday - extrai o dia da semana de uma determinada data, valor numerico
# 0 = monday e 6 = sunday

#     df['dia_semana'] = df['dia_semana'].map(mapa) - converte o valor de acordo com mapeamento em uma lista e ja substitui o valor da coluna

#     mapa = {
#         0:'Segunda',
#         1:'Terça',
#         2:'Quarta',
#         3:'Quinta',
#         4:'Sexta',
#         5:'Sábado',
#         6:'Domingo',
#     }

# pd.crosstab(df.estado, df.sexo) - cria uma tabela cruzada com os parametros que desejarmos

# df[df.aprovado].sexo.value_counts().plot(kind='pie',        - Criação de um gráfico de pizza ou pie para contar
#                                         autopct='%.2f%%',     o % entre aprovados por sexo
#                                         startangle=90) 
# plt.title('Aprovados')
# plt.plot()

# para mais informações, biblioteca completa pandas e seaborn:

# https://seaborn.pydata.org/
# https://pandas.pydata.org/docs/
