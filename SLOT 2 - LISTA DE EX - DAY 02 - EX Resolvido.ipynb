# %% [markdown]
# ALAN CRISTOFER - RID#35201

# %% [markdown]
# # Ex 01

# %%
x = 5
print(type(x))
# Out:
# <class 'int'>

# %%
x = 5.0
print(type(x))
# Out:
# <class 'float'>

# %%
x = 5.5
print(type(x))
# Out:
# <class 'float'>

# %%
x = 'DNC'
print(type(x))
# Out:
# <class 'str'>

# %%
x = ½
print(type(x))
# Out:
#   File "<ipython-input-5-dcb689fe895e>", line 1
#     x = ½
#         ^
# SyntaxError: invalid character in identifier

# %%
x = 0.5 * 2
print(type(x))
# Out:
# <class 'float'>

# %%
x = 2 ** 4
print(type(x))
# Out:
# <class 'int'>

# %%
x = 2+4
print(type(x))
# Out:
# <class 'int'>

# %%
x = 1000000000
print(type(x))
# Out:
# <class 'int'>

# %%
x = int(input('Insira um número inteiro: '))

print(type(x))
# Out:
# Insira um número inteiro: 5
# <class 'int'>

# %%
x = float(input('Insira um número float: '))

print(type(x))
# Out:
# Insira um número float: 5.2
# <class 'float'>

# %%
x = str(input('Insira um dado: '))

print(type(x))
# Out:
# Insira um dado: 52
# <class 'str'>

# %%
x = input('Insira um dado: ')

print(type(x))
# Out:
# Insira um dado: 52
# <class 'str'>

# %% [markdown]
# # Ex 02

# %%
print('-'*50)
print('-'*50)
print(' '*19,'DS05 - DNC')
print('-'*50)
print('-'*50)
# Out:
# --------------------------------------------------
# --------------------------------------------------
#                     DS05 - DNC
# --------------------------------------------------
# --------------------------------------------------

# %% [markdown]
# # Ex 03

# %%
salario_cientista_de_dados = 10000.00
parcela_bmw = 2500.45
parcela_apartamento = 3500.50
veterinario_romeuzinho = 500.00
luz = 100.80
agua = 80.35
condominio = 800.44
gas = 150.65

contas = (parcela_bmw + parcela_apartamento + veterinario_romeuzinho + luz + agua + condominio + gas)
poupanca = salario_cientista_de_dados - contas

print(f'O seu salário é de R$ {salario_cientista_de_dados:1.0f}')
print()
print(f'O valor total das suas contas é de R$ {contas:.2f}')
print()
print(f'Te sobra R$ {poupanca:.2f} para investir')
# Out:
# O seu salário é de R$ 10000
#
# O valor total das suas contas é de R$ 7633.19
#
# Te sobra R$ 2366.81 para investir

# %% [markdown]
# # Ex 04

# %%
print('-'*50)
print('-'*50)
print(' '*16,'Bem-vindo à DNC')
print('-'*50)
print('-'*50)
print('Temos os seguintes cursos:')
print()
print('1. Formação em dados')
print('2. Formação em projetos')
print('3. Formação em marketing')
print('4. Formação em produto')
print('5. Formação em tecnologia')
print('-'*50)

cursos = ['0','Formação em dados',
          'Formação em projetos',
          'Formação em marketing',
          'Formação em produto',
          'Formação em tecnologia',]

valores = [0,20000.00,15000.00,13000.00,18000.00,19000.00]

op_curso = int(input('Qual curso você quer escolher (1, 2, 3, 4, 5)? '))
print('-'*50)
if op_curso != 1 and op_curso != 2 and op_curso != 3 and op_curso != 4 and op_curso != 5:
  print("Valor inválido. Digite um valor correspondente a um curso de nossas formações \n1-Formação em dados \n2-Formação em projetos \n3-Formação em marketing \n4-Formação em produto \n5-Formação em tecnologia")
else:
  esc = cursos[op_curso]
  print(f'Você escolheu o curso {esc}, o valor deste curso é de R$ {valores[op_curso]} que começará no próximo mês')
# Out:
# --------------------------------------------------
# --------------------------------------------------
#                  Bem-vindo à DNC
# --------------------------------------------------
# --------------------------------------------------
# Temos os seguintes cursos:
#
# 1. Formação em dados
# 2. Formação em projetos
# 3. Formação em marketing
# 4. Formação em produto
# 5. Formação em tecnologia
# --------------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     728             try:
# --> 729                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     730             except Exception:
#
# /usr/local/lib/python3.7/dist-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# /usr/local/lib/python3.7/dist-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     726         """
# --> 727         parts = [self.recv(flags, copy=copy, track=track)]
#     728         # have first part already, only loop while more to receive
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._recv_copy()
#
# /usr/local/lib/python3.7/dist-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-86-a77fd5421ebb> in <module>()
#      21 valores = [0,20000.00,15000.00,13000.00,18000.00,19000.00]
#      22
# ---> 23 op_curso = int(input('Qual curso você quer escolher (1, 2, 3, 4, 5)? '))
#      24 print('-'*50)
#      25 if op_curso != 1 and op_curso != 2 and op_curso != 3 and op_curso != 4 and op_curso != 5:
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     702             self._parent_ident,
#     703             self._parent_header,
# --> 704             password=False,
#     705         )
#     706
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     732             except KeyboardInterrupt:
#     733                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 734                 raise KeyboardInterrupt
#     735             else:
#     736                 break
#
# KeyboardInterrupt:

# %% [markdown]
# # Ex 05

# %%
cursos = ['Formação em dados',
          'Formação em projetos',
          'Formação em marketing',
          'Formação em produto',
          'Formação em tecnologia',]

valores = [20000.00,15000.00,13000.00,18000.00,19000.00]

print(cursos)
print(valores)
print()

print(' '*16,'CONTABILIZANDO AS VENDAS')
print('-'*50)
vendas = []
s1 = 0
for v in range(0,len(cursos)):
  vaux = int(input(f'Insira o total de vendas para o curso {cursos[v]}: '))
  vendas.append(vaux)
print('-'*50)
vtotal = 0
for c,v1,v2 in zip(cursos, vendas, valores):
    print(f'{c:<23} - {v1:<1} - R$ {v2:.2f}. Valor total = {v1 * v2:.2f}')
    vtotal += (v1 * v2)
print('-'*50)
if vtotal >= 1000000:
  print(f'Vendas Gerais: {sum(vendas)}')
  print(f'Valor total vendido: R$ {vtotal:.2f}')
  print(f"Parabéns!!! A DNC bateu a meta do mês")
else:
  print(f'Vendas Gerais: {sum(vendas)}')
  print(f'Valor Total em Vendas: R$ {vtotal:.2f}')
  print(f"Esse mês não batemos a meta, porém mês que vem vamos vir mais forte pra recuperar!!!")
# Out:
# ['Formação em dados', 'Formação em projetos', 'Formação em marketing', 'Formação em produto', 'Formação em tecnologia']
# [20000.0, 15000.0, 13000.0, 18000.0, 19000.0]
#
#                  CONTABILIZANDO AS VENDAS
# --------------------------------------------------
# Insira o total de vendas para o curso Formação em dados: 45
# Insira o total de vendas para o curso Formação em projetos: 30
# Insira o total de vendas para o curso Formação em marketing: 20
# Insira o total de vendas para o curso Formação em produto: 35
# Insira o total de vendas para o curso Formação em tecnologia: 42
# --------------------------------------------------
# Formação em dados       - 45 - R$ 20000.00. Valor total = 900000.0
# Formação em projetos    - 30 - R$ 15000.00. Valor total = 450000.0
# Formação em marketing   - 20 - R$ 13000.00. Valor total = 260000.0
# Formação em produto     - 35 - R$ 18000.00. Valor total = 630000.0
# Formação em tecnologia  - 42 - R$ 19000.00. Valor total = 798000.0
# --------------------------------------------------
# Vendas Gerais: 172
# Valor total vendido: R$ 3038000.0
# Parabéns!!! A DNC bateu a meta do mês

# %% [markdown]
# # Ex 06

# %%
seq = int(input("Insira o número: "))
soma = 0
for i in range(1,seq+1):
  soma += i
  print(f'Código: {soma}')
# Out:
# Insira o número: 10
# Código: 1
# Código: 3
# Código: 6
# Código: 10
# Código: 15
# Código: 21
# Código: 28
# Código: 36
# Código: 45
# Código: 55

# %% [markdown]
# # Ex 07

# %%
while True:
  f = input('Deseja trocar de música: [P - Sim] ')

  if f != 'p':
    print("Opção diferente de P fecha o sistema")
    break
  else:
    print('*Musica mudou*')
# Out:
# Deseja trocar de música: [P - Sim] p
# *Musica mudou*
# Deseja trocar de música: [P - Sim] p
# *Musica mudou*
# Deseja trocar de música: [P - Sim] n
# Opção diferente de P fecha o sistema

# %% [markdown]
# # Ex 08

# %%
alunos = []

for a in range(1,3+1):
  aux = input('Insira o nome: ')
  alunos.append(aux)
print()
for i in alunos:
  print(f'Parabens {i} pelo seu trabalho duro!')
# Out:
# Insira o nome: a
# Insira o nome: b
# Insira o nome: c
#
# Parabens a pelo seu trabalho duro!
# Parabens b pelo seu trabalho duro!
# Parabens c pelo seu trabalho duro!

# %% [markdown]
# # Ex 09

# %%
moedas = []

while True:
  aux = int(input('Insira a moeda: '))
  moedas.append(aux)
  f = input('Deseja continuar? [S/N] ')
  if f == 'n':
    break
print("*"*502)
print(f'Você possui {len(moedas)} moedas')
print(f'Você possui R$ {sum(moedas)/100:.2f} reais')
# Out:
# Insira a moeda: 10
# Deseja continuar? [S/N] n
# **********************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************
# Você possui 1 moedas
# Você possui R$ 0.10 reais

# %% [markdown]
# # Ex 10

# %%
cad = {}
pessoas = []

while True:
  cad['nome'] = input("Digite o nome a ser cadastrado: ")
  cad['rid'] = input("Digite o RID a ser cadastrado: ")
  cad['idade'] = input("Digite a idade a ser cadastrada: ")
  cad['cidade'] = input("Digite a cidade a ser cadastrada: ")
  cad['cargo'] = input("Digite o cargo a ser cadastrado: ")
  pessoas.append(cad.copy())
  f = input("Deseja continuar? [s/n]: " )
  if f == "n":
    break
print()
print("Dados cadastrados com sucesso!")

print(cad)
# Out:
# Digite o nome a ser cadastrado: Alan
# Digite o RID a ser cadastrado: 35201
# Digite a idade a ser cadastrada: 28
# Digite a cidade a ser cadastrada: São Paulo
# Digite o cargo a ser cadastrado: Cientista de Dados
# Deseja continuar? [s/n]: n
#
# Dados cadastrados com sucesso!
# {'nome': 'Alan', 'rid': '35201', 'idade': '28', 'cidade': 'São Paulo', 'cargo': 'Cientista de Dados'}

# %% [markdown]
# # Ex 11

# %%
def vnotas():
  notas = []
  while True:
    aux = float(input('Insira o valor da nota: '))
    notas.append(aux)
    f = input('Deseja continuar? [S/N] ')
    if f == 'n':
      print("*"*60)
      print(f'Você possui {len(notas)} notas')
      print(f'Você possui R$ {sum(notas):.2f} reais')
      break

# %%
vnotas()
# Out:
# Insira o valor da nota: 25
# Deseja continuar? [S/N] s
# Insira o valor da nota: 25
# Deseja continuar? [S/N] n
# ************************************************************
# Você possui 2 notas
# Você possui R$ 50.00 reais
