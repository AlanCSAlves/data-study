# %%
mport matplotlib.pyplot as plt
valores = [15,30, 45, 10]
rotulos = ['Frogs', 'Hogs', 'Dogs', 'Logs']
explode = [0, .1, 0, 0]
cores = ['brown', 'orange', 'green', 'red']

plt.figure(figsize=(7,7))

plt.pie(
    valores,
    explode=explode,
    labels=rotulos,
    colors=cores,
    autopct='%.1f%%',
    shadow=True,
    startangle=90,
    )



plt.show()

# %%
import numpy as np
x = [1.2, 2.5, 3.3, 4.1, 4.4, 5]
y = [65, 35, 22, 50, 18, 15] #15
cores = ['red', 'green', 'yellow', 'yellow', 'green', 'red']
tamanho = np.array([100, 60, 40, 80, 30, 70]) * 2

plt.scatter(
    x, y,
    s=tamanho,
    c=cores,
    # alpha=.5,
    # marker='>'
    # cmap='Set1',
    # norm=
    # vmin=0,
    # vmax=1
    # linewidths=40
)
plt.xticks(np.arange(1.0,5.1,0.5))
plt.yticks(range(10,61,10))
plt.show()

# %%
x = ['Python', 'C++', 'Java', 'Perl', 'Scala', 'Lisp']
y = [10, 8, 6, 4, 2, 1]

plt.bar(x, y, alpha=.8, color='mediumslateblue', edgecolor='black', linewidth=.9)
plt.ylim(0,10)
plt.ylabel('Usage')
plt.title('Programing Language Usage')
plt.show()

# %%
x = ['Python', 'C++', 'Java', 'Perl', 'Scala', 'Lisp']
y = [10, 8, 6, 4, 2, 1]

plt.barh(x, y, alpha=.8, color='mediumslateblue', edgecolor='black', linewidth=.6)
plt.xlim(0,10)
plt.xlabel('Usage')
plt.title('Programing Language Usage')
plt.show()

# %%
help(plt.bar)
# Out:
# Help on function bar in module matplotlib.pyplot:
#
# bar(x, height, width=0.8, bottom=None, *, align='center', data=None, **kwargs)
#     Make a bar plot.
#
#     The bars are positioned at *x* with the given *align*\ment. Their
#     dimensions are given by *width* and *height*. The vertical baseline
#     is *bottom* (default 0).
#
#     Each of *x*, *height*, *width*, and *bottom* may either be a scalar
#     applying to all bars, or it may be a sequence of length N providing a
#     separate value for each bar.
#
#     Parameters
#     ----------
#     x : sequence of scalars
#         The x coordinates of the bars. See also *align* for the
#         alignment of the bars to the coordinates.
#
#     height : scalar or sequence of scalars
#         The height(s) of the bars.
#
#     width : scalar or array-like, optional
#         The width(s) of the bars (default: 0.8).
#
#     bottom : scalar or array-like, optional
#         The y coordinate(s) of the bars bases (default: 0).
# ...
