# %% [markdown]
# **INFORMAÇÕES RELEVANTES SOBRE A BIBLIOTECA MATPLOT**

# %%
#DISCLAIMER IMPORTANTE

# o comando help(função) também pode ser de grande ajuda para verificar os demais elementos que possuem os requisitos.

# Biblioteca sys contém funções do sistema, podemos usar para medir o tamanho código
# Biblioteca time contém funções de tempo, podemos usar para medir o tempo de execução do código

# O python sempre considera o 0 para navegar entre os dados

# Fórmulas do matplotlib quer podem ser úteis:

# import matplotlib.pyplot as plt
# plt.figure(figsize=(7,7)) - tamanho do gráfico, possui um efeito melhor se vem antes das informações
# devemos definir os arrays com o valores específicos para monstar os gráficos, pois ele utilizará os elementos dentro das listas, ex:

#   valores = [15, 30, 45, 10] - valor dos itens
#   rotulos = ['Frogs', 'Hogs', 'Dogs', 'Logs'] - itens do gráfico
#   explode = [0, .1, 0, 0] - destaque dos itens, .1 = 10%
#   cores = ['blue', 'orange', 'green', 'red'] - cores associadas a cada item

# a disposição fica da seguinte forma:

#     plt.pie(                  - gráfico de pizza
#         valores,              - valores
#         explode=explode,      - destaque
#         labels=rotulos,       - legendas
#         colors=cores,         - cores
#         autopct='%.1f%%',     - formato dos valores dos itens
#         shadow=True,          - sombra do gráfico, personalização
#         startangle=90,        - rotação do gráfico
#         )

# ele pode ser ainda mais personalizavel, basta acessarmos a função help(plt.pie) para verficarmos todos os parametros possíveis.

# plt.show() - remove as informações do gráfico
# para facilitar, podemos usar o numpy para gerar os arrays para manipular melhor as listas
# utilizandos os seguintes valores:

#       x = [1.2, 2.5, 3.3, 4.1, 4.4, 5]
#       y = [65, 35, 22, 50, 18, 15] #15
#       cores = ['red', 'green', 'yellow', 'yellow', 'green', 'red']
#       tamanho = np.array([100, 60, 40, 80, 30, 70]) * 2

# os graficos de pontos podem ser dispostos da seguinte forma:

#       plt.scatter(            - gráfico modelo de pontos 
#           x, y,               - eixos
#           s=tamanho,          - tamanho dos marcadores
#           c=cores,            - cores do gráfico
#           )                   

# plt.xticks(np.arange(1.0,5.1,0.5)) - define os valores da legenda do eixo x
# plt.yticks(range(10,61,10))        - define os valores da legenda do eixo y

# assim como o pie, mais personalizações podem ser conferidas utilizando o help(plt.scatter)

# utilizandos os seguintes valores:

#       x = ['Python', 'C++', 'Java', 'Perl', 'Scala', 'Lisp']
#       y = [10, 8, 6, 4, 2, 1]

# graficos de barras podem ser dispostos da seguinte forma:

#        plt.bar(
#                x, y,                            - eixo x e y
#                alpha=.8,                        - claridade da cor, quanto menor, mais claro
#                color='mediumslateblue',         - cor
#                edgecolor='black',               - cor da borda
#                linewidth=.6                     - grossura da linha borda
#                )

# plt.ylabel('Usage') - título na linha de y
# plt.title('Programing Language Usage') - título do gráfico
# plt.ylim(0,10) - define o limite da barra das linhas de y

# em comparativo, grafico de barras horizontais:

#        plt.barh(
#                x, y,                            - eixo x e y
#                alpha=.8,                        - claridade da cor, quanto menor, mais claro
#                color='mediumslateblue',         - cor
#                edgecolor='black',               - cor da borda
#                linewidth=.6                     - grossura da linha borda
#                )

# plt.xlabel('Usage') - título na linha de x (invertido)
# plt.title('Programing Language Usage') - título do gráfico
# plt.xlim(0,10) - define o limite da barra das linhas de x (invertido)

# assim como os outros, mais personalizações podem ser conferidas utilizando o help(plt.bar/barh)

# para mais informações, biblioteca completa matplot:

# https://matplotlib.org/
